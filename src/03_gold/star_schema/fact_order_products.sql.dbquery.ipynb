-- %%
-- Fact: Order Products (grain: one row per product per order)
CREATE OR REPLACE TABLE instacart_gold.order_products AS
SELECT
  op.order_id,
  op.product_id,
  op.add_to_cart_order,
  op.reordered
FROM instacart_silver.order_products op;
