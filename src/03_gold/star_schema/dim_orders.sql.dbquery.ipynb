-- %%
-- Dimension: Orders
CREATE OR REPLACE TABLE instacart_gold.orders AS
SELECT
  order_id,
  user_id,
  eval_set,
  order_number,
  order_dow,
  order_hour_of_day,
  days_since_prior_order
FROM instacart_silver.orders;
