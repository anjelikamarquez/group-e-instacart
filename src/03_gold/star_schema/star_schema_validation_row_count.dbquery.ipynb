-- %%
-- Gold layer table row counts
SELECT 'orders' AS table_name, COUNT(*) AS row_count FROM instacart_gold.orders
UNION ALL
SELECT 'products', COUNT(*) FROM instacart_gold.products
UNION ALL
SELECT 'order_products', COUNT(*) FROM instacart_gold.order_products
ORDER BY table_name;
