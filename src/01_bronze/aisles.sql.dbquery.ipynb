-- %%
CREATE TABLE IF NOT EXISTS instacart.aisles AS
SELECT *
FROM read_files('/Volumes/workspace/default/ftw-b12-r2/shared/week06/instacart_csv/aisles.csv',
format => 'csv',
header => true,
schema => 'aisle_id INT, aisle STRING'
);
