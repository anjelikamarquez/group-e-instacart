-- %%
CREATE TABLE IF NOT EXISTS instacart.order_products AS
SELECT *
FROM read_files('/Volumes/workspace/default/ftw-b12-r2/shared/week06/instacart_csv/order_products__prior.csv',
format => 'csv',
header => true,
schema => 'order_id INT, product_id INT, add_to_cart_order INT, reordered INT'
)
