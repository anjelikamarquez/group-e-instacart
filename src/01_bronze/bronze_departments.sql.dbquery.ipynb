-- %%
CREATE TABLE IF NOT EXISTS instacart.departments AS
SELECT *
FROM read_files('/Volumes/workspace/default/ftw-b12-r2/shared/week06/instacart_csv/departments.csv',
format => 'csv',
header => true,
schema => 'department_id INT, department STRING'
);
