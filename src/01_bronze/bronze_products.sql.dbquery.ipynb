-- %%
CREATE TABLE IF NOT EXISTS instacart.products AS
SELECT *
FROM read_files('/Volumes/workspace/default/ftw-b12-r2/shared/week06/instacart_csv/products.csv',
format => 'csv',
header => true,
schema => 'product_id INT, product_name STRING, aisle_id INT, department_id INT'
);
